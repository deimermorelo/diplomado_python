# %% [markdown]
# ## Solucion al Taller 3
#
# ### Diplomado Python Aplicado a la Ingenieria UPB
#
# * Autor: Deimer David Morelo Ospino
# * ID: 502217
# * Email: deimer.morelo@upb.edu.co

# %%
print(chr(27)+"[1;31m"+"***********************************************************************************************************************")
print(chr(27)+"[1;31m"+"                                                BIENVENIDOS A CINEPYTHON") 
print(chr(27)+"[1;31m"+"                                             ¡Diversion para toda la familia!") 
print("***********************************************************************************************************************")

import random 
import IPython.display as display
from PIL import Image
display.display(Image.open('cinepython2.jpg'))

sub_sala=0
sala=""
sub_precio_sala=0
cont=""
comidas=""
cant_comida=0
precio_comida=0
sub_comida=0
bebidas=""
cant_bebida=0
precio_bebida=0
sub_bebida=0
valor_tipo_contenido=0
cantidad_tiempo=0

def total_por_pagar(t_alquiler, t_comidas, t_bebidas):
    total_por_pagar=t_alquiler+t_comidas+t_bebidas
    return total_por_pagar

acceso=(input("¿Desea acceder a nuestros servicios (SI/NO)?: "))
acceso2=acceso.lower()
nombre=input("Por favor ingrese su nombre y apellido: \n")
identificacion=input("Por favor ingrese su numero de identificacion: \n")
telefono=input("Por favor ingrese su numero de telefono: \n")


if(acceso2=="si"):  
    flag = True
    while flag:
        choice = input("""
SERVICIOS DISPONIBLES. 
Seleccione una opción:
  1. Alquiler de salas
  2. Comidas
  3. Bebidas
  4. Generar factura
  0. Salir
        """)
        if choice =="1":
            print("*********************************")
            print(" MENU ALQUILER DE SALAS DE CINE")
            print("*********************************")
            precio_sala=0
            tipo_contenido=0
            sala=int(input("Por favor seleccione el tipo de sala que desea alquilar (1, 2, 3, 4, 5 o 6): "
                       +"\n1. Sala 2D (Maximo 10 personas)----------$45.000 por hora"
                       +"\n2. Sala 2D (Maximo 20 personas)----------$80.000 por hora"
                       +"\n3. Sala 3D (Maximo 10 personas)----------$60.000 por hora"
                       +"\n4. Sala 3D (Maximo 20 personas)----------$100.000 por hora"
                       +"\n5. Sala 4D (Maximo 10 personas)----------$150.000 por hora"
                       +"\n6. Sala 4D (Maximo 20 personas)----------$250.000 por hora\n"))
    
            if(sala==1):
                precio_sala=45000
                sala="Sala 2D para 10 personas"
            elif(sala==2):
                precio_sala=80000
                sala="Sala 2D para 20 personas"
            elif(sala==3):
                precio_sala=60000
                sala="Sala 3D para 10 personas"
            elif(sala==4):
                precio_sala=100000
                sala="Sala 3D para 20 personas"
            elif(sala==5):
                precio_sala=150000
                sala="Sala 4D para 10 personas"
            elif(sala==6):
                precio_sala=250000
                sala="Sala 2D para 20 personas"
    
            tiempo=int(input("\nPor favor seleccione la cantidad de tiempo (1, 2, 3, 4, 5 o 6): "
                       +"\n1. 2 Horas"
                       +"\n2. 4 Horas"
                       +"\n3. 6 Horas"
                       +"\n4. 8 Horas"
                       +"\n5. 10 Horas"
                       +"\n6. 12 Horas\n"))
            if(tiempo==1):
                cantidad_tiempo=2
            elif(tiempo==2):
                cantidad_tiempo=4
            elif(tiempo==3):
                cantidad_tiempo=6
            elif(tiempo==4):
                cantidad_tiempo=8
            elif(tiempo==5):
                cantidad_tiempo=10
            elif(tiempo==6):
                cantidad_tiempo=12
            contenido=int(input("\nPor favor seleccione el tipo de contenido audiovisual que desea ver (1 o 2): "
                       +"\n1. Pelicula----------$20.000"
                       +"\n2. Serie-------------$35.000\n"))
            if(contenido==1):
                tipo_contenido=20000
                cont="Alquiler Pelicula"
                valor_tipo_contenido=tipo_contenido
            elif(contenido==2):
                tipo_contenido=35000
                cont="Alquiler Serie"
                valor_tipo_contenido=tipo_contenido
            def subtotal_sala(sala, tiempo, contenido):
                subtotal=((precio_sala*cantidad_tiempo)+tipo_contenido)
                return subtotal
            sub_precio_sala=(precio_sala*cantidad_tiempo)
            sub_sala=subtotal_sala(precio_sala, cantidad_tiempo, tipo_contenido)
                        
        elif choice =="2":
            print("***************************")
            print("   COMBOS DISPONIBLES")
            print("***************************")
            combos=int(input("Por favor seleccione el combo que desea adquirir (1, 2 o 3): "
                       +"\n1. COMBO 1--------------------------$18.000"
                       +"\n-Palomitas de maiz (Envase pequeño)"
                       +"\n-Nachos"
                       +"\n-Bolsa de papas"
                       +"\n-Manzana acaramelada"
                       +"\n-Gaseosa\n"
                       +"\n2. COMBO 2--------------------------$25.000"
                       +"\n-Palomitas de maiz (Envase Mediano)"
                       +"\n-Nachos"
                       +"\n-Bolsa de papas"
                       +"\n-Manzana acaramelada"
                       +"\n-Perro caliente"
                       +"\n-Pizza personal"
                       +"\n-Barra de chocolate"
                       +"\n-Gaseosa\n"
                       +"\n3. COMBO 3--------------------------$33.000"
                       +"\n-Palomitas de maiz (Envase grande)"
                       +"\n-Nachos"
                       +"\n-Bolsa de papas"
                       +"\n-Manzana acaramelada"
                       +"\n-Perro caliente"
                       +"\n-Pizza familiar"
                       +"\n-Barra de chocolate"
                       +"\n-Helado de yogurt"
                       +"\n-Hamburguesa"
                       +"\n-Gaseosa\n"))   
           
            if(combos==1):
                precio_comida=18000
                comidas="COMBO 1"
            elif(combos==2):
                precio_comida=25000
                comidas="COMBO 2"
            elif(combos==3):
                precio_comida=33000
                comidas="COMBO 3"            
            cantidad=int(input("Por favor ingrese la cantidad de unidades a adquirir: "))
            cant_comida=cantidad
            def subtotal_comida(valor_combo, cantidad):
                subtotal=(precio_comida*cantidad)
                return subtotal                     
            sub_comida=subtotal_comida(precio_comida, cantidad) 
        elif choice =="3":
            print("***************************")
            print("   BEBIDAS DISPONIBLES")
            print("***************************")
            beb=int(input("Por favor seleccione la bebida que desea adquirir (1, 2 o 3): "
                       +"\n1. Coca Cola------------------------$5.000"
                       +"\n2. Malteada de Fresa----------------$8.000"
                       +"\n3. Malteada de Mora-----------------$8.000"
                       +"\n4. Limonada Cerezada ---------------$6.000"
                       +"\n5. Cerveza Budweiser----------------$10.000"
                       +"\n6. Té helado -----------------------$9.000\n"))   
           
            if(beb==1):
                precio_bebida=5000
                bebidas="Coca Cola"
            elif(beb==2):
                precio_bebida=8000
                bebidas="Malteada de Fresa"
            elif(beb==3):
                precio_bebida=8000
                bebidas="Malteada de Mora"
            if(beb==4):
                precio_comida=6000
                comidas="Limonada Cerezada"
            elif(beb==5):
                precio_comida=10000
                comidas="Cerveza Budweiser"
            elif(beb==6):
                precio_comida=9000
                comidas="Té Helado"
            cantidad=int(input("Por favor ingrese la cantidad de unidades a adquirir: "))
            cant_bebida=cantidad
            def subtotal_bebida(valor_bebida, cantidad):
                subtotal=(precio_bebida*cantidad)
                return subtotal                     
            sub_bebida=subtotal_bebida(precio_bebida, cantidad)

        elif choice =="4":
            num_factura=str(random.randint(910010, 910110))
            print("***********************************************************************************************************************")
            def factura():
                return ("CINEPYTHON"+"\n¡Diversion para toda la familia!"+"\n\nFACTURA DE VENTA No. "+num_factura+"             Fecha: 27/05/2022"
                        +"\n\nFacturar a:\n"+"Cliente: "+nombre+"\nIdentificación: "+identificacion+"\nTelefono: "+telefono
                        +"\n\nDescripcion     "+sala+"("+str(cantidad_tiempo)+"h)"+"  "+cont+"  "+comidas+"  "+bebidas
                        +"\nCantidad                       1"+"                     1"+"               "+str(cant_comida)+"           "+str(cant_bebida)
                        +"\nPrecio Unitario             "+str(precio_sala)+"/h                "+str(valor_tipo_contenido)+"           "+str(precio_comida)+"        "+str(precio_bebida)
                        +"\n\nTOTAL A PAGAR------------------------------$"+str(total_por_pagar(sub_sala, sub_comida, sub_bebida))) 
            print(factura())
            print("***********************************************************************************************************************")
            with open('Factura.txt', 'a') as text_file:
                text_file.write(factura())
            print(chr(27)+"[1;32m"+"¡Gracias por visitarnos. Que tenga un buen día!")
            break
        elif choice == "0":
            print(chr(27)+"[1;32m"+"¡Gracias por visitarnos. Que tenga un buen día!")
            break

else:
    print(chr(27)+"[1;32m"+"¡Gracias por visitarnos. Que tenga un buen día!")
# Out:
# ***********************************************************************************************************************
#                                                 BIENVENIDOS A CINEPYTHON
#                                              ¡Diversion para toda la familia!
# ***********************************************************************************************************************
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=1172x756 at 0x2CFC3F7EF70>
# ¿Desea acceder a nuestros servicios (SI/NO)?: si
# Por favor ingrese su nombre y apellido:
# 1
# Por favor ingrese su numero de identificacion:
# 1
# Por favor ingrese su numero de telefono:
# 1
#
# SERVICIOS DISPONIBLES.
# Seleccione una opción:
#   1. Alquiler de salas
#   2. Comidas
#   3. Bebidas
#   4. Generar factura
#   0. Salir
#         1
# *********************************
#  MENU ALQUILER DE SALAS DE CINE
# *********************************
# ...
